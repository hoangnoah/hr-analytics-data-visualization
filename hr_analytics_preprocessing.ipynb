# %% [markdown]
# ### Import một số thư viện cần thiết

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Đọc dữ liệu và xử lý NaN

# %%
df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition_DIRTY.csv', na_values=["na", "nn", "nan","NaN", "null", "none", " "])
df.replace(r'^\s*$', np.nan, regex=True, inplace=True)
print(f"📥 Đã đọc: {df.shape[0]} hàng, {df.shape[1]} cột")
df.head()
# Out:
# 📥 Đã đọc: 1608 hàng, 36 cột
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0  41.0       Yes                NaN     1123.0                   Sales
# 1  48.0        No  Travel_Frequently      273.0  Research & Development
# 2  37.0       NaN      Travel_Rarely        NaN  Research & Development
# 3  32.0        No  Travel_Frequently     1395.0  Research & Development
# 4  27.0        No      Travel_Rarely      585.0  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0               1.0        2.0  Life Sciences            NaN               1
# 1               8.0        1.0  Life Sciences            1.0               2
# 2               2.0        2.0          Other            1.0               4
# 3               2.0        4.0  Life Sciences            1.0               5
# 4               2.0        1.0        Medical            1.0               7
#
#    ...  StandardHours StockOptionLevel  TotalWorkingYears  \
# 0  ...           80.0              0.0                7.0
# 1  ...           80.0              1.0               12.0
# 2  ...           80.0              0.0                7.0
# 3  ...           80.0              0.0                8.0
# 4  ...           80.0              1.0                6.0
#
#    TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                    0.0              1.0            6.0                 4.0
# 1                    3.0              3.0           10.0                 7.0
# 2                    3.0              3.0            0.0                 0.0
# 3                    3.0              3.0            8.0                 NaN
# 4                    3.0              3.0            2.0                 2.0
#
#   YearsSinceLastPromotion  YearsWithCurrManager  DateOfResignation
# 0                     0.0                   5.0   11/25/2021 10:30
# 1                     1.0                   7.0     8/9/2019 10:30
# 2                     0.0                   0.0    4/12/2017 10:30
# 3                     3.0                   0.0    3/23/2021 10:30
# 4                     2.0                   2.0     5/7/2021 10:30
#
# [5 rows x 36 columns]

# %% [markdown]
# ### 2. Xoá trùng lặp

# %%
before = df.shape[0]
df = df.drop_duplicates()
print(f"✅ Đã xoá {before - df.shape[0]} dòng trùng lặp")
# Out:
# ✅ Đã xoá 138 dòng trùng lặp

# %% [markdown]
# ### 3. Xử lý missing values

# %%
# 1. Đếm giá trị NaN trước xử lý
missing_before = df.isna().sum().sum()
print(f"❓ Số giá trị còn thiếu trước xử lý: {missing_before}")
# 2. Xác định cột số và cột chuỗi
num_cols = df.select_dtypes(include=np.number).columns
cat_cols = df.select_dtypes(include='object').columns

# 3. Cột số → điền giá trị trung bình (mean)
df[num_cols] = df[num_cols].fillna(df[num_cols].mean(numeric_only=True))

# 4. Cột chuỗi → điền giá trị phổ biến nhất (mode)
for col in cat_cols:
    if df[col].isnull().sum() > 0:
        df[col] = df[col].fillna(df[col].mode(dropna=True)[0])

# 5. In thông tin sau xử lý
print("🧼 Đã xử lý missing values.")
print(f"Số giá trị còn thiếu sau xử lý: {df.isna().sum().sum()}")
df.head()  # Hiển thị bảng dữ liệu đầu tiên
# Out:
# ❓ Số giá trị còn thiếu trước xử lý: 2460
# 🧼 Đã xử lý missing values.
# Số giá trị còn thiếu sau xử lý: 0
#     Age Attrition     BusinessTravel    DailyRate              Department  \
# 0  41.0       Yes      Travel_Rarely  1123.000000                   Sales
# 1  48.0        No  Travel_Frequently   273.000000  Research & Development
# 2  37.0        No      Travel_Rarely   826.244253  Research & Development
# 3  32.0        No  Travel_Frequently  1395.000000  Research & Development
# 4  27.0        No      Travel_Rarely   585.000000  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0               1.0        2.0  Life Sciences            1.0               1
# 1               8.0        1.0  Life Sciences            1.0               2
# 2               2.0        2.0          Other            1.0               4
# 3               2.0        4.0  Life Sciences            1.0               5
# 4               2.0        1.0        Medical            1.0               7
#
#    ...  StandardHours StockOptionLevel  TotalWorkingYears  \
# 0  ...           80.0              0.0                7.0
# 1  ...           80.0              1.0               12.0
# 2  ...           80.0              0.0                7.0
# 3  ...           80.0              0.0                8.0
# 4  ...           80.0              1.0                6.0
#
#    TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                    0.0              1.0            6.0            4.000000
# 1                    3.0              3.0           10.0            7.000000
# 2                    3.0              3.0            0.0            0.000000
# 3                    3.0              3.0            8.0            4.415658
# 4                    3.0              3.0            2.0            2.000000
#
#   YearsSinceLastPromotion  YearsWithCurrManager  DateOfResignation
# 0                     0.0                   5.0   11/25/2021 10:30
# 1                     1.0                   7.0     8/9/2019 10:30
# 2                     0.0                   0.0    4/12/2017 10:30
# 3                     3.0                   0.0    3/23/2021 10:30
# 4                     2.0                   2.0     5/7/2021 10:30
#
# [5 rows x 36 columns]

# %% [markdown]
# ### 4. Chuẩn hoá chuỗi: strip + title

# %%
# Hàm chuẩn hoá: loại bỏ khoảng trắng, chuẩn hóa chữ viết thường
def clean_text(text):
    if pd.isna(text): return text
    return str(text).strip().lower()

# Áp dụng trước: chuẩn hoá sơ bộ tất cả chuỗi
for col in cat_cols:
    df[col] = df[col].apply(clean_text)

# Với các cột dễ bị lỗi chính tả → chỉ giữ top phổ biến
for col in ['Department', 'JobRole', 'BusinessTravel']:
    top_values = df[col].value_counts().index[:3]  # Top 3 giá trị đúng thường gặp nhất
    df[col] = df[col].apply(lambda x: x if x in top_values else np.nan)
    df[col] = df[col].fillna(df[col].mode(dropna=True)[0])

# Optional: viết hoa chữ cái đầu sau khi làm sạch
for col in cat_cols:
    df[col] = df[col].apply(lambda x: str(x).title() if pd.notna(x) else x)

# In 5 giá trị đầu mỗi cột chuỗi
print("🔤 Đã chuẩn hoá + lọc lỗi chính tả bằng tần suất:")
for col in cat_cols:
    print(f"\n📌 Cột `{col}` sau xử lý:")
    print(df[col].dropna().unique()[:5])
# Out:
# 🔤 Đã chuẩn hoá + lọc lỗi chính tả bằng tần suất:
#
# 📌 Cột `Attrition` sau xử lý:
# ['Yes' 'No']
#
# 📌 Cột `BusinessTravel` sau xử lý:
# ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
#
# 📌 Cột `Department` sau xử lý:
# ['Sales' 'Research & Development' 'Human Resources']
#
# 📌 Cột `EducationField` sau xử lý:
# ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree']
#
# 📌 Cột `Gender` sau xử lý:
# ['Female' 'Male']
#
# 📌 Cột `JobRole` sau xử lý:
# ['Sales Executive' 'Research Scientist' 'Laboratory Technician']
#
# 📌 Cột `MaritalStatus` sau xử lý:
# ['Single' 'Married' 'Divorced']
#
# 📌 Cột `Over18` sau xử lý:
# ['Y']
#
# 📌 Cột `OverTime` sau xử lý:
# ['Yes' 'No']
#
# 📌 Cột `DateOfResignation` sau xử lý:
# ['11/25/2021 10:30' '8/9/2019 10:30' '4/12/2017 10:30' '3/23/2021 10:30'
#  '5/7/2021 10:30']

# %% [markdown]
# ### 5. Làm tròn tất cả cột số nếu có thể

# %%
# 🔢 Làm tròn các cột số và chuyển về kiểu int nếu phù hợp
rounded_cols = []  # Danh sách lưu tên các cột đã ép kiểu về int

for col in num_cols:
    # Bỏ qua giá trị NaN và kiểm tra xem tất cả có phải số nguyên không (modulo 1 == 0)
    if (df[col].dropna() % 1 == 0).all():
        df[col] = df[col].astype(int)
        rounded_cols.append(col)
    else:
        # Nếu có số thập phân, thử làm tròn trước
        df[col] = df[col].round()
        # Sau khi làm tròn, nếu tất cả đều là số nguyên thì ép kiểu int
        if (df[col].dropna() % 1 == 0).all():
            df[col] = df[col].astype(int)
            rounded_cols.append(col)

# ✅ In ra các cột đã được ép về kiểu int
if rounded_cols:
    print("🔢 Các cột số đã được làm tròn và ép về kiểu `int`:")
    for col in rounded_cols:
        print(f"  - {col}")
else:
    print("⚠️ Không có cột số nào đủ điều kiện để ép về kiểu `int`.")
# Out:
# 🔢 Các cột số đã được làm tròn và ép về kiểu `int`:
#   - Age
#   - DailyRate
#   - DistanceFromHome
#   - Education
#   - EmployeeCount
#   - EmployeeNumber
#   - EnvironmentSatisfaction
#   - HourlyRate
#   - JobInvolvement
#   - JobLevel
#   - JobSatisfaction
#   - MonthlyIncome
#   - MonthlyRate
#   - NumCompaniesWorked
#   - PercentSalaryHike
#   - PerformanceRating
#   - RelationshipSatisfaction
#   - StandardHours
#   - StockOptionLevel
#   - TotalWorkingYears
#   - TrainingTimesLastYear
#   - WorkLifeBalance
#   - YearsAtCompany
#   - YearsInCurrentRole
#   - YearsSinceLastPromotion
#   - YearsWithCurrManager

# %% [markdown]
# ### 6. Clip outliers bằng IQR

# %%
# 📉 Hàm clip giá trị ngoại lai bằng IQR
def clip_outliers(df, cols):
    clipped_cols = []  # Danh sách cột đã được xử lý outliers

    for col in cols:
        Q1 = df[col].quantile(0.25)  # Phân vị thứ 1 (25%)
        Q3 = df[col].quantile(0.75)  # Phân vị thứ 3 (75%)
        IQR = Q3 - Q1  # Khoảng tứ phân vị

        lower = Q1 - 1.5 * IQR  # Ngưỡng dưới
        upper = Q3 + 1.5 * IQR  # Ngưỡng trên

        # Lưu lại cột nếu có ít nhất 1 giá trị bị clip
        if ((df[col] < lower) | (df[col] > upper)).any():
            clipped_cols.append(col)

        # Áp dụng clipping
        df[col] = df[col].clip(lower, upper)

    # In kết quả
    if clipped_cols:
        print("📉 Đã xử lý outliers bằng IQR cho các cột:")
        for col in clipped_cols:
            print(f"  - {col}")
    else:
        print("✅ Không phát hiện outliers vượt ngưỡng IQR nào cần clip.")

    return df

# Gọi hàm xử lý
df = clip_outliers(df, num_cols)

#7. Làm tròn lại nếu clip tạo số thập phân
for col in num_cols:
    df[col] = df[col].round()

# Nếu toàn bộ giá trị sau làm tròn là số nguyên thì chuyển kiểu dữ liệu từ float -> int
converted_to_int = []
for col in num_cols:
    if (df[col].dropna() % 1 == 0).all():  # Kiểm tra xem tất cả đều là số nguyên
        df[col] = df[col].astype(int)
        converted_to_int.append(col)

if converted_to_int:
    print("🔢 Các cột đã được ép kiểu về int:", converted_to_int)
else:
    print("ℹ️ Không có cột nào đủ điều kiện để ép về int.")
# Out:
# 📉 Đã xử lý outliers bằng IQR cho các cột:
#   - Age
#   - DailyRate
#   - DistanceFromHome
#   - Education
#   - HourlyRate
#   - JobLevel
#   - MonthlyIncome
#   - MonthlyRate
#   - NumCompaniesWorked
#   - PercentSalaryHike
#   - PerformanceRating
#   - StockOptionLevel
#   - TotalWorkingYears
#   - TrainingTimesLastYear
#   - YearsAtCompany
#   - YearsInCurrentRole
#   - YearsSinceLastPromotion
#   - YearsWithCurrManager
# 🔢 Các cột đã được ép kiểu về int: ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %% [markdown]
# ### Loại bỏ các dòng có giá trị âm trong bất kỳ cột số nào

# %%
num_cols = df.select_dtypes(include=[np.number]).columns

negative_mask = (df[num_cols] < 0).any(axis=1)

rows_with_negatives = df[negative_mask].shape[0]

negatives = {}
for col in num_cols:
    if (df[col] < 0).any():
        negatives[col] = df[df[col] < 0][col].unique()
if negatives:
    print("❗ Các cột có chứa giá trị âm:")
    for col, vals in negatives.items():
        print(f"  - {col}: {list(vals)}")
else:
    print("✅ Không phát hiện giá trị âm trong bất kỳ cột số nào.")
df = df[~negative_mask]
print(f"🗑️ Đã loại bỏ {rows_with_negatives} dòng có giá trị âm trong cột số")
# Out:
# ❗ Các cột có chứa giá trị âm:
#   - YearsAtCompany: [np.int64(-1)]
#   - YearsInCurrentRole: [np.int64(-1)]
# 🗑️ Đã loại bỏ 5 dòng có giá trị âm trong cột số

# %% [markdown]
# ### 8. Lưu kết quả

# %%
output_path = "./dataset/hr_employee_attrition.csv"
df.to_csv(output_path, index=False)
print(f"💾 Đã lưu file sạch tại: {output_path}")
# Out:
# 💾 Đã lưu file sạch tại: WA_Fn-UseC_-HR-Employee-Attrition_CLEAN_FOR_VIS.csv

# %% [markdown]
# ### 5 dòng đầu sau khi làm sạch

# %%
df2 = pd.read_csv(output_path)
df2.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1123                   Sales
# 1   48        No  Travel_Frequently        273  Research & Development
# 2   37        No      Travel_Rarely        826  Research & Development
# 3   32        No  Travel_Frequently       1395  Research & Development
# 4   27        No      Travel_Rarely        585  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 2          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  StandardHours StockOptionLevel  TotalWorkingYears  \
# 0  ...             80                0                  7
# 1  ...             80                1                 12
# 2  ...             80                0                  7
# 3  ...             80                0                  8
# 4  ...             80                1                  6
#
#    TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                      0                1              6                   4
# 1                      3                3             10                   7
# 2                      3                3              0                   0
# 3                      3                3              8                   4
# 4                      3                3              2                   2
#
#   YearsSinceLastPromotion  YearsWithCurrManager  DateOfResignation
# 0                       0                     5   11/25/2021 10:30
# 1                       1                     7     8/9/2019 10:30
# 2                       0                     0    4/12/2017 10:30
# 3                       3                     0    3/23/2021 10:30
# 4                       2                     2     5/7/2021 10:30
#
# [5 rows x 36 columns]
